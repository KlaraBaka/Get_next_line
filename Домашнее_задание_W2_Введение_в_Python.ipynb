# %% [markdown]
# <a href="https://colab.research.google.com/github/KlaraBaka/Get_next_line/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_W2_%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B2_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # **Домашнее задание. W2. Введение в Python**
#
# Корректировка таблицы с ивентами.
#
# **Контекст**
#
# Одним из основных направлений продуктовой аналитики в онлайн-кинотеатре *CentralCinema* является обработка и настройка **ивентов** (то есть продуктовых событий, которые *логируются* в таблицы).
#
# У нас есть несколько таблиц, в которые заливаются логи продуктовых ивентов, однако на данный момент они недостаточно формализованы, чтобы с ними было удобно работать.
#
# Необходимо создать функцию в Python, которая будет брать на вход датафрейм и проводить все необходимые преобразования, чтобы датафрейм стал более интерпретируемым и подходящим для процессов аналитики.
#
# **Проблема**
#
# Логи ивентов находятся в плохо интерпретируемой форме.
#
# **Цель**
#
# С помощью регулярных выражений настроить очистку и преобразование таблицы с продуктовыми логами в соответствии с&nbsp;требованиями, указанными ниже.

# %% [markdown]
# ## Импорт данных
#
# Импортируй локально файл под названием *«Event_Log_HW_W2.xlsx»*.
#
# В нём содержится одна колонка, с которой тебе необходимо работать в следующих пяти заданиях.

# %%
### Твой код здесь

# %% [markdown]
# ## Задание 1 (3 балла)
#
# Выдели идентификатор ивента в отдельную колонку и сделай эту колонку индексом датафрейма.
#
# Идентификатор ивента — это подстрока поля *name_event*, которая находится перед первым нижним подчёркиванием.
#
# Обрати внимание, что:
#  - в некоторых строках вместо подчёркивания может встретиться восклицательный знак;
#  - идентификаторы ивента имеют нефиксированную длину;
#  - могут быть лишние пробелы в начале и конце строки (здесь тебе поможет метод *strip*);
#  - если поле *name_event* начинается с нуля, то этот ноль необходимо заменить на единицу.

# %%
### Твой код здесь

# %% [markdown]
# ## Задание 2 (2 балла)
#
# После нижнего подчёркивания идёт буквенное обозначение типа события: клик, скролл и так далее.
#
# Выдели данное буквенное обозначение в отдельную колонку.
#
# Обрати внимание, что разные типы ивентов могут иметь разное количество букв в своём обозначении.
#
# **Подсказка: для решения задачи тебе могут потребоваться символы "(", ")", "\D" и "*".**

# %%
### Твой код здесь

# %% [markdown]
# ## Задание 3 (1 балл)
#
# Выдели в отдельную колонку идентификатор клиента, который совершил действие.
#
# Идентификатор клиента идёт сразу после названия типа ивента и заканчивается открывающейся квадратной скобкой.
#
# Обрати внимание, что идентификаторы клиента имеют нефиксированную длину.

# %%
### Твой код здесь

# %% [markdown]
# ## Задание 4 (2 балла)
#
# Выдели в отдельную колонку первые три цифры телефонного номера клиента (после +7). Данные цифры содержатся в квадратных скобках и могут отсутствовать в рамках некоторых клиентов.
#
# Помести эти три цифры в отдельную колонку, возьми в круглые скобки и напиши в начале +7.

# %%
### Твой код здесь

# %% [markdown]
# ## Задание 5 (2 балла)
#
# Проставь флаг (*True*/*False*), показывающий, является пользователь зарегистрированным или нет.
#
# Для этого обрати внимание на символы после квадратных скобок.
#
# Если последовательность этих символов содержит "Reg", то пользователя можно считать зарегистрированным.
#
# Обрати внимание, что вокруг "Reg" может быть любое количество символов.

# %%
### Твой код здесь
